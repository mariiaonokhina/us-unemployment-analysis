# %% [raw]
# analyzing and cleaning:
#
# III. 2015- 2023 The Employment Cost Index (ECI):
# Link to Dataset: Tables : U.S. Bureau of Labor Statistics
# File format: Excel
# Approximate File size: 2.4MB
# Approximate Number of records: 35,622
# Purpose: to measure the change in the hourly labor cost to employers over time.
#
# IV. 2015 - 2023 Consumer Price Index:
# Link to Dataset: Archived Consumer Price Index Supplemental Files : U.S. Bureau of
# Labor Statistics
# File format: Excel
# Approximate File size: 12.8KB
# Approximate Number of records: 45
# Purpose: to monitor inflation over time.

# %%
# !pip install pyspark dask pandas matplotlib openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyspark in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (3.3.1)
# Requirement already satisfied: dask in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (2025.9.1)
# Requirement already satisfied: pandas in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (3.10.6)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: py4j==0.10.9.5 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from pyspark) (0.10.9.5)
# Requirement already satisfied: click>=8.1 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from dask) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from dask) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from dask) (2025.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from dask) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from dask) (1.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from matplotlib) (3.2.4)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: locket in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from partd>=1.4.0->dask) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/csgyc-6513-fall/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %% [raw]
# ECI

# %%
plt.figure(figsize=(10,5))
plt.plot(years, eci_values, marker="o", label="ECI: Labor Cost Growth")
# plt.plot(cpi_yearly["year"], cpi_yearly["inflation_rate"], marker="o", label="CPI: Inflation")
plt.title("ECI (Yearly Average)")
plt.xlabel("Year")
plt.ylabel("Percent Change (%)")
plt.legend()
plt.grid(True)
plt.show()
